# %% [markdown]
# <a href="https://colab.research.google.com/github/evgeny-kolonsky/gaza-news/blob/main/news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # News crawler

# %%
# !pip install gnews

# %%
import urllib, urllib.request, time, datetime
import requests
from bs4 import BeautifulSoup
from datetime import date, timedelta
import json
from gnews import GNews

# %%
# get URL after redirect
def get_redirected(url):
  try:
    redirected = requests.get(url, allow_redirects=True, timeout=1).url
  except:
    redirected = url
  return redirected

# %%
# set here start date, final date and filename for data saving

KEYWORD = '"ABC News" + gaza'

FORMAT = '%Y/%m/%d'
start_day = datetime.datetime.strptime('2024/01/01', FORMAT)
fin_day   = datetime.datetime.strptime('2024/06/30', FORMAT)


google_news = GNews()

filename = 'abc-news.txt'

# clear file
file = open(filename, 'w')
file.close()

urls = {} # urls collection to check for duplicates

day = start_day
while day < fin_day:
  print(day, end='')
  google_news.start_date = day
  nextday = day + timedelta(days=1)
  google_news.end_date =  nextday
  news = google_news.get_news(KEYWORD)
  lines = ''
  for headline in news:
    google_url = headline['url']
    original_url = get_redirected(google_url)

    if original_url in urls:
      continue
    else:
      urls[original_url] = True

    title = headline['title']
    publisher = headline['publisher']['title']
    line = f'{day:%Y-%m-%d}\t{publisher}\t{title}\t{original_url}\n'
    lines += line
  print(' ', len(news))
  with open(filename, 'a') as f:
    f.write(lines)
  day = nextday
# Out:
# 2024-01-01 00:00:00  10
# 2024-01-02 00:00:00  8
# 2024-01-03 00:00:00  9
# 2024-01-04 00:00:00  9
# 2024-01-05 00:00:00  9
# 2024-01-06 00:00:00  7
# 2024-01-07 00:00:00  7
# 2024-01-08 00:00:00  10
# 2024-01-09 00:00:00  10
# 2024-01-10 00:00:00  12
# 2024-01-11 00:00:00  13
# 2024-01-12 00:00:00  10
# 2024-01-13 00:00:00  9
# 2024-01-14 00:00:00  8
# 2024-01-15 00:00:00  10
# 2024-01-16 00:00:00  9
# 2024-01-17 00:00:00  11
# 2024-01-18 00:00:00  9
# 2024-01-19 00:00:00  10
# 2024-01-20 00:00:00  9
# 2024-01-21 00:00:00  8
# 2024-01-22 00:00:00  11
# 2024-01-23 00:00:00  11
# 2024-01-24 00:00:00  9
# 2024-01-25 00:00:00  14
# 2024-01-26 00:00:00  14
# 2024-01-27 00:00:00  8
# 2024-01-28 00:00:00  10
# 2024-01-29 00:00:00  14
# 2024-01-30 00:00:00  12
# 2024-01-31 00:00:00  13
# 2024-02-01 00:00:00  9
# 2024-02-02 00:00:00  9
# 2024-02-03 00:00:00  9
# 2024-02-04 00:00:00  9
# 2024-02-05 00:00:00  10
# 2024-02-06 00:00:00  9
# 2024-02-07 00:00:00  9
# 2024-02-08 00:00:00  8
# 2024-02-09 00:00:00  9
# 2024-02-10 00:00:00  19
# 2024-02-11 00:00:00  23
# 2024-02-12 00:00:00  11
# 2024-02-13 00:00:00  9
# 2024-02-14 00:00:00  10
# 2024-02-15 00:00:00  10
# 2024-02-16 00:00:00  9
# 2024-02-17 00:00:00  9
# 2024-02-18 00:00:00  8
# 2024-02-19 00:00:00  11
# 2024-02-20 00:00:00  15
# 2024-02-21 00:00:00  12
# 2024-02-22 00:00:00  10
# 2024-02-23 00:00:00  9
# 2024-02-24 00:00:00  8
# 2024-02-25 00:00:00  9
# 2024-02-26 00:00:00  10
# 2024-02-27 00:00:00  13
# 2024-02-28 00:00:00  15
# 2024-02-29 00:00:00  13
# 2024-03-01 00:00:00  13
# 2024-03-02 00:00:00  17
# 2024-03-03 00:00:00  17
# 2024-03-04 00:00:00  9
# 2024-03-05 00:00:00  9
# 2024-03-06 00:00:00  19
# 2024-03-07 00:00:00  26
# 2024-03-08 00:00:00  15
# 2024-03-09 00:00:00  11
# 2024-03-10 00:00:00  17
# 2024-03-11 00:00:00  18
